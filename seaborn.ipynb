# %% [markdown]
# **Distribution Plots**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Histogram Distribution-Univariant

# %%
sns.displot(tips['total_bill'],kde=True,bins=10)
plt.show()

# %% [markdown]
# Bivariant plot

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')
plt.show()

# %%
sns.pairplot(tips,hue='sex',palette='coolwarm')

plt.show()

# %%
sns.rugplot(tips['total_bill'])
plt.show()

# %%
sns.kdeplot(tips['total_bill'])
plt.show()

# %% [markdown]
# **CATEGORICAL PLOTS**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import numpy as np

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)
plt.show()

# %%
sns.countplot(x='sex',data=tips)
plt.show()

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='smoker')
plt.show()

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='sex',split=True)
plt.show()

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=True,hue='sex')
plt.show()

# %%
sns.swarmplot(x='day',y='total_bill',data=tips)
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=tips,kind='bar')
plt.show()

# %% [markdown]
# **Matrix Plot**

# %%
flights=sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
tc=tips.select_dtypes(include='number').corr()

# %%
sns.heatmap(tc,annot=True,cmap='coolwarm')
plt.show()

# %%
fp=flights.pivot_table(index='month',columns='year',values='passengers')
# Out:
# C:\Users\prabu\AppData\Local\Temp\ipykernel_2368\2534965686.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   fp=flights.pivot_table(index='month',columns='year',values='passengers')

# %%
sns.heatmap(fp,cmap='magma')
plt.show()

# %%
sns.clustermap(fp,standard_scale=1)
plt.show()

# %% [markdown]
# **GRIDS**

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
g=sns.PairGrid(iris)
g.map_diag(sns.histplot)
g.map_upper(plt.scatter)
g.map(sns.kdeplot)
plt.show()
# Out:
# C:\Users\prabu\anaconda3_new\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   func(x=x, y=y, **kwargs)
# C:\Users\prabu\anaconda3_new\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   func(x=x, y=y, **kwargs)

# %%
g=sns.FacetGrid(data=tips,col='time',row='smoker')
g.map(sns.histplot,'total_bill')
plt.show()

# %% [markdown]
# **Regression Plots**

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',markers=['o','v'],scatter_kws={'s':100})
plt.show()
